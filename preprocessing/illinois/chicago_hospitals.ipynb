# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
hospitals_df = gpd.read_file("chicago_hospital/Hospital_Chicago.shp")
hospitals_df
# Out:
#     OBJECTID          ID                                               NAME  \
# 0       4534  0004060640                    LOUIS A WEISS MEMORIAL HOSPITAL
# 1        500  0009760609                      METHODIST HOSPITAL OF CHICAGO
# 2       7524  0010860657                     PRESENCE SAINT JOSEPH HOSPITAL
# 3        495  0005560613                           THOREK MEMORIAL HOSPITAL
# 4        499  0009060657           ADVOCATE ILLINOIS MASONIC MEDICAL CENTER
# 5       4116  0007360612                    UNIVERSITY OF ILLINOIS HOSPITAL
# 6       4532  0007460624                              SACRED HEART HOSPITAL
# 7       3436  0005960612                     RUSH UNIVERSITY MEDICAL CENTER
# 8        496  0006260612                         JOHN H STROGER JR HOSPITAL
# 9       7194  0002060624  RML HEALTH PROVIDERS LIMITED PARTNERSHIP - DBA...
# 10      6354  0001060608                   MT SINAI HOSPITAL MEDICAL CENTER
# ...

# %%
hospitals_df.to_file('chicago_hospitals.geojson', driver='GeoJSON', encoding='utf-8')
print('done')
# Out:
# done
