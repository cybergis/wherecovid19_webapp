# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
countries = gpd.read_file("World_Countries_Boundaries/World_Countries_Boundaries.shp")
cases = pd.read_csv("05-25-2020.csv")

# %%
countries
# Out:
#      OBJECTID           CNTRY_NAME  \
# 0           1                Aruba
# 1           2  Antigua and Barbuda
# 2           3          Afghanistan
# 3           4              Algeria
# 4           5           Azerbaijan
# ..        ...                  ...
# 246       247        Western Samoa
# 247       248            Swaziland
# 248       249                Yemen
# 249       250               Zambia
# 250       251             Zimbabwe
#
#                                               geometry
# 0    POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1    MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2    POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3    POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4    MULTIPOLYGON (((45.02583 41.03055, 45.00999 41...
# ..                                                 ...
# 246  MULTIPOLYGON (((-172.59650 -13.50911, -172.551...
# 247  POLYGON ((30.89944 -26.77195, 30.88028 -26.793...
# ...

# %%
cases
# Out:
#          FIPS     Admin2  Province_State      Country_Region  \
# 0     45001.0  Abbeville  South Carolina                  US
# 1     22001.0     Acadia       Louisiana                  US
# 2     51001.0   Accomack        Virginia                  US
# 3     16001.0        Ada           Idaho                  US
# 4     19001.0      Adair            Iowa                  US
# ...       ...        ...             ...                 ...
# 3404      NaN        NaN             NaN  West Bank and Gaza
# 3405      NaN        NaN             NaN      Western Sahara
# 3406      NaN        NaN             NaN               Yemen
# 3407      NaN        NaN             NaN              Zambia
# 3408      NaN        NaN             NaN            Zimbabwe
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 0     2020-05-26 02:32:35  34.223334  -82.461707         35       0
# 1     2020-05-26 02:32:35  30.295065  -92.414197        299      18
# ...

# %%
country_cases = cases.groupby('Country_Region').sum()
country_cases
# Out:
#                     FIPS        Lat      Long_  Confirmed  Deaths  Recovered  \
# Country_Region
# Afghanistan          0.0  33.939110  67.709953      11173     219       1097
# Albania              0.0  41.153300  20.168300       1004      32        795
# Algeria              0.0  28.033900   1.659600       8503     609       4747
# Andorra              0.0  42.506300   1.521800        763      51        663
# Angola               0.0 -11.202700  17.873900         70       4         18
# ...                  ...        ...        ...        ...     ...        ...
# West Bank and Gaza   0.0  31.952200  35.233200        423       3        357
# Western Sahara       0.0  24.215500 -12.885800          9       0          6
# Yemen                0.0  15.552727  48.516388        233      44         10
# Zambia               0.0 -13.133897  27.849332        920       7        336
# Zimbabwe             0.0 -19.015438  29.154857         56       4         25
#
#                     Active
# ...

# %%
country_cases = country_cases.drop(columns=['FIPS','Lat','Long_'])
country_cases
# Out:
#                     Confirmed  Deaths  Recovered  Active
# Country_Region
# Afghanistan             11173     219       1097    9857
# Albania                  1004      32        795     177
# Algeria                  8503     609       4747    3147
# Andorra                   763      51        663      49
# Angola                     70       4         18      48
# ...                       ...     ...        ...     ...
# West Bank and Gaza        423       3        357      63
# Western Sahara              9       0          6       3
# Yemen                     233      44         10     179
# Zambia                    920       7        336     577
# Zimbabwe                   56       4         25      27
#
# [188 rows x 4 columns]

# %%
country_cases['Country'] = country_cases.index
country_cases
# Out:
#                     Confirmed  Deaths  Recovered  Active             Country
# Country_Region
# Afghanistan             11173     219       1097    9857         Afghanistan
# Albania                  1004      32        795     177             Albania
# Algeria                  8503     609       4747    3147             Algeria
# Andorra                   763      51        663      49             Andorra
# Angola                     70       4         18      48              Angola
# ...                       ...     ...        ...     ...                 ...
# West Bank and Gaza        423       3        357      63  West Bank and Gaza
# Western Sahara              9       0          6       3      Western Sahara
# Yemen                     233      44         10     179               Yemen
# Zambia                    920       7        336     577              Zambia
# Zimbabwe                   56       4         25      27            Zimbabwe
#
# [188 rows x 5 columns]

# %%
worldwide_cases = pd.merge(countries, country_cases,  how='left', left_on=['CNTRY_NAME'], right_on = ['Country'])

# %%
worldwide_cases
# Out:
#      OBJECTID           CNTRY_NAME  \
# 0           1                Aruba
# 1           2  Antigua and Barbuda
# 2           3          Afghanistan
# 3           4              Algeria
# 4           5           Azerbaijan
# ..        ...                  ...
# 246       247        Western Samoa
# 247       248            Swaziland
# 248       249                Yemen
# 249       250               Zambia
# 250       251             Zimbabwe
#
#                                               geometry  Confirmed  Deaths  \
# 0    POLYGON ((-69.88223 12.41111, -69.94695 12.436...        NaN     NaN
# 1    MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...       25.0     3.0
# 2    POLYGON ((61.27656 35.60725, 61.29638 35.62853...    11173.0   219.0
# 3    POLYGON ((-5.15213 30.18047, -5.13917 30.19236...     8503.0   609.0
# 4    MULTIPOLYGON (((45.02583 41.03055, 45.00999 41...     4271.0    51.0
# ..                                                 ...        ...     ...
# ...

# %%
worldwide_cases.crs
# Out:
# {'init': 'epsg:4326'}

# %%
worldwide_cases.to_file("worldwide_data.geojson", driver="GeoJSON")
